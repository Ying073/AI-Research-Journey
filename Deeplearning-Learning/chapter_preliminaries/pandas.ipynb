# %% [markdown]
# # 数据预处理
# ## 创建一个人工数据集，并存储在csv文件

# %%
import os

os.makedirs(os.path.join('..','data'),exist_ok=True)
data_file=os.path.join('..','data','house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRoom,Alley,Price\n')
    f.write('NA,Pave,12750\n')
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,140000\n')

# %% [markdown]
# ## 从创建的csv文件中加载原始数据集

# %%
import pandas as pd

data=pd.read_csv(data_file)
data
# Out:
#    NumRoom Alley   Price
# 0      NaN  Pave   12750
# 1      2.0   NaN  106000
# 2      4.0   NaN  178100
# 3      NaN   NaN  140000

# %% [markdown]
# ## 为了处理缺失的数据，典型的方法包括 插值 和 删除，这里，我们将考虑插值

# %%
inputs,outputs=data.iloc[:,0:2],data.iloc[:,2]
inputs=inputs.fillna(inputs.mean(numeric_only=True))
print(inputs)
# Out:
#    NumRoom Alley
# 0      3.0  Pave
# 1      2.0   NaN
# 2      4.0   NaN
# 3      3.0   NaN

# %% [markdown]
# ## 对于inputs中的类别值或离散值，我们将“NaN”视作一个类别

# %%
inputs=pd.get_dummies(inputs,dummy_na=True)
print(inputs)
# Out:
#    NumRoom  Alley_Pave  Alley_nan
# 0      3.0        True      False
# 1      2.0       False       True
# 2      4.0       False       True
# 3      3.0       False       True

# %% [markdown]
# ## 现在inputs和 outputs中的所有条目都是数值类型， 它们可以转换为张量格式

# %%
import torch

inputs = inputs.astype(float)
X,y=torch.tensor(inputs.values),torch.tensor(outputs.values)
X ,y
# Out:
# (tensor([[3., 1., 0.],
#          [2., 0., 1.],
#          [4., 0., 1.],
#          [3., 0., 1.]], dtype=torch.float64),
#  tensor([ 12750, 106000, 178100, 140000]))
